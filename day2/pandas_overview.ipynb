# %%
import pandas as pd

# %%
dfa = pd.read_excel("file_example_XLSX_5000.xlsx")

# %%
dfa
# Out:
#       Unnamed: 0 First Name   Last Name  Gender        Country  Age  \
# 0              1      Dulce       Abril  Female  United States   32
# 1              2       Mara   Hashimoto  Female  Great Britain   25
# 2              3     Philip        Gent    Male         France   36
# 3              4   Kathleen      Hanner  Female  United States   25
# 4              5    Nereida     Magwood  Female  United States   58
# ...          ...        ...         ...     ...            ...  ...
# 4995        4996       Roma  Lafollette  Female  United States   34
# 4996        4997     Felisa        Cail  Female  United States   28
# 4997        4998   Demetria       Abbey  Female  United States   32
# 4998        4999     Jeromy        Danz    Male  United States   39
# 4999        5000   Rasheeda      Alkire  Female  United States   29
#
#             Date    Id
# 0     15/10/2017  1562
# 1     16/08/2016  1582
# 2     21/05/2015  2587
# 3     15/10/2017  3549
# 4     16/08/2016  2468
# ...

# %%
dfb = pd.read_csv("international-migration-September-2020-estimated-migration-by-age-sex.csv")

# %%
dfb
# Out:
#       year_month month_of_release     passenger_type direction     sex  \
# 0        2019-05          2020-09  Long-term migrant  Arrivals  Female
# 1        2019-06          2020-09  Long-term migrant  Arrivals  Female
# 2        2019-07          2020-09  Long-term migrant  Arrivals  Female
# 3        2019-08          2020-09  Long-term migrant  Arrivals  Female
# 4        2019-09          2020-09  Long-term migrant  Arrivals  Female
# ...          ...              ...                ...       ...     ...
# 42180    2018-12          2020-09  Long-term migrant       Net   TOTAL
# 42181    2019-01          2020-09  Long-term migrant       Net   TOTAL
# 42182    2019-02          2020-09  Long-term migrant       Net   TOTAL
# 42183    2019-03          2020-09  Long-term migrant       Net   TOTAL
# 42184    2019-04          2020-09  Long-term migrant       Net   TOTAL
#
#              age  estimate  standard_error       status
# 0      0-4 years       316               0        Final
# ...

# %%
dfa.shape
# Out:
# (5000, 8)

# %%
dfb.shape
# Out:
# (42185, 9)

# %%
dfb.head(8)
# Out:
#   year_month month_of_release     passenger_type direction     sex        age  \
# 0    2019-05          2020-09  Long-term migrant  Arrivals  Female  0-4 years
# 1    2019-06          2020-09  Long-term migrant  Arrivals  Female  0-4 years
# 2    2019-07          2020-09  Long-term migrant  Arrivals  Female  0-4 years
# 3    2019-08          2020-09  Long-term migrant  Arrivals  Female  0-4 years
# 4    2019-09          2020-09  Long-term migrant  Arrivals  Female  0-4 years
# 5    2019-10          2020-09  Long-term migrant  Arrivals  Female  0-4 years
# 6    2019-11          2020-09  Long-term migrant  Arrivals  Female  0-4 years
# 7    2019-12          2020-09  Long-term migrant  Arrivals  Female  0-4 years
#
#    estimate  standard_error       status
# 0       316               0        Final
# 1       340               0  Provisional
# 2       357               1  Provisional
# 3       421               2  Provisional
# 4       396               3  Provisional
# ...

# %%
dfb['passenger_type']
# Out:
# 0        Long-term migrant
# 1        Long-term migrant
# 2        Long-term migrant
# 3        Long-term migrant
# 4        Long-term migrant
#                ...
# 42180    Long-term migrant
# 42181    Long-term migrant
# 42182    Long-term migrant
# 42183    Long-term migrant
# 42184    Long-term migrant
# Name: passenger_type, Length: 42185, dtype: object

# %%
dfb['passenger_type'].nunique()
# Out:
# 1

# %%
dfb['passenger_type'].unique()
# Out:
# array(['Long-term migrant'], dtype=object)

# %%
dfb['direction'].nunique()
# Out:
# 3

# %%
dfb['direction'].value_counts()
# Out:
# Arrivals      14123
# Departures    14094
# Net           13968
# Name: direction, dtype: int64

# %%
dfb['sex'].value_counts()
# Out:
# TOTAL     14220
# Female    14037
# Male      13928
# Name: sex, dtype: int64

# %%
dfb['status'].value_counts()
# Out:
# Final          39334
# Provisional     2851
# Name: status, dtype: int64

# %%
dfb [(dfb['direction'] == 'Arrivals')  & (dfb['sex'] == 'Female')]
# Out:
#       year_month month_of_release     passenger_type direction     sex  \
# 0        2019-05          2020-09  Long-term migrant  Arrivals  Female
# 1        2019-06          2020-09  Long-term migrant  Arrivals  Female
# 2        2019-07          2020-09  Long-term migrant  Arrivals  Female
# 3        2019-08          2020-09  Long-term migrant  Arrivals  Female
# 4        2019-09          2020-09  Long-term migrant  Arrivals  Female
# ...          ...              ...                ...       ...     ...
# 40420    2018-12          2020-09  Long-term migrant  Arrivals  Female
# 40421    2019-01          2020-09  Long-term migrant  Arrivals  Female
# 40422    2019-02          2020-09  Long-term migrant  Arrivals  Female
# 40423    2019-03          2020-09  Long-term migrant  Arrivals  Female
# 40424    2019-04          2020-09  Long-term migrant  Arrivals  Female
#
#              age  estimate  standard_error       status
# 0      0-4 years       316               0        Final
# ...

# %%
dfb_temp = dfb [(dfb['direction'] == 'Arrivals')  & (dfb['sex'] == 'Female')]

# %%
dfb_temp
# Out:
#       year_month month_of_release     passenger_type direction     sex  \
# 0        2019-05          2020-09  Long-term migrant  Arrivals  Female
# 1        2019-06          2020-09  Long-term migrant  Arrivals  Female
# 2        2019-07          2020-09  Long-term migrant  Arrivals  Female
# 3        2019-08          2020-09  Long-term migrant  Arrivals  Female
# 4        2019-09          2020-09  Long-term migrant  Arrivals  Female
# ...          ...              ...                ...       ...     ...
# 40420    2018-12          2020-09  Long-term migrant  Arrivals  Female
# 40421    2019-01          2020-09  Long-term migrant  Arrivals  Female
# 40422    2019-02          2020-09  Long-term migrant  Arrivals  Female
# 40423    2019-03          2020-09  Long-term migrant  Arrivals  Female
# 40424    2019-04          2020-09  Long-term migrant  Arrivals  Female
#
#              age  estimate  standard_error       status
# 0      0-4 years       316               0        Final
# ...

# %%
dfb_temp.to_excel("thursday.xlsx")

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
